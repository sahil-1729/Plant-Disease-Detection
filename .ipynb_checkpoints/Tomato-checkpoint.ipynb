# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
batch_size = 32
image_size = 256

# %%
dataset = tf.keras.utils.image_dataset_from_directory("Batata",batch_size = batch_size, image_size=(image_size,image_size),shuffle=True)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
print(tf.__version__)
# Out:
# 2.16.0-rc0

# %%
# Folder names will be class names

# %%
dataset_name = dataset.class_names
dataset_name
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
# 68 because images are in the form of batches where each batch is 32

# %%
len(dataset)
# Out:
# 68

# %%
plt.figure(figsize=(10,10))

for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        # subplot -> rows X columns -> 3,4 -> 3*4 -> 12 itesm in total
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(dataset_name[label_batch[i]])
        plt.axis("off")

# %% [markdown]
#  ### 80% used for training data
# ### 20% mese => 10% used for validation and rest 10 used for testing data

# %% [markdown]
# ### Get the len of training data

# %%
train_size = 0.8
train_size*len(dataset)
# Out:
# 54.400000000000006

# %%
train_dataset = dataset.take(54)
len(train_dataset)
# Out:
# 54

# %%
test_and_validation_dataset = dataset.skip(54)
len(test_and_validation_dataset)
# Out:
# 14

# %%
len(dataset)*0.1
# Out:
# 6.800000000000001

# %%
validation_ds = test_and_validation_dataset.take(6)
len(validation_ds)
# Out:
# 6

# %%
test_ds = test_and_validation_dataset.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partition(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=12)
    
    train_size = int(train_split*ds_size)
    val_size = int(val_split*ds_size)
    
    train_ds = ds.take(train_size)

    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, test_ds, val_ds

# %%
train_ds, test_ds, val_ds = get_dataset_partition(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(test_ds)
# Out:
# 8

# %%
len(val_ds)
# Out:
# 6

# %% [markdown]
# ### Optimization

# %%
train_ds = train_ds.cache().shuffle(10000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(10000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(10000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Preprocessing (Scaling-converting the numbers from 0-255 to 0-1 | Resizing-changing the size of images, which might be more than image_size(variable) to fixed size)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(image_size,image_size),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip(mode="horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(factor=0.2)
])

# %%
# convo2d -> convolutional model

n_classes = 3
channels = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    # relu is taken bc it is fast
    layers.Convolution2D(32,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPool2D((2,2)),

    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax')
])

model.build(input_shape=(batch_size, image_size,image_size,channels))
# Out:
# C:\Users\Sahil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (32, 254, 254, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (32, 127, 127, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (32, 516128)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (32, 64)                    │      33,032,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (32, 3)                     │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,033,347 (126.01 MB)
#  Trainable params: 33,033,347 (126.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
# history = model.fit(train_dataset,batch_size=batch_size,validation_data=validation_ds,verbose=1,epochs=50)

# %% [markdown]
# ### CHeck score of the model

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.4330 - loss: 1.0284

# %%
scores
# Out:
# [1.0136640071868896, 0.47265625]

# %%
# convo2d -> convolutional model

n_classes = 3
channels = 3

new_model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    # relu is taken bc it is fast
    layers.Conv2D(32,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),

    # repeat isliye kiya, to improve the accuracy 
    layers.Conv2D(64,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),

layers.Conv2D(64,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),

    # added new layer
    layers.Conv2D(64,(3,3),activation='relu', input_shape=(batch_size, image_size,image_size,channels) ),
    layers.MaxPooling2D((2,2)),
    
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax')
])

new_model.build(input_shape=(batch_size, image_size,image_size,channels))
# Out:
# C:\Users\Sahil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
new_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (32, 254, 254, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (32, 127, 127, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (32, 125, 125, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (32, 62, 62, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (32, 60, 60, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (32, 30, 30, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (32, 28, 28, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (32, 14, 14, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (32, 12, 12, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (32, 6, 6, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (32, 4, 4, 64)              │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (32, 2, 2, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (32, 256)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (32, 64)                    │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (32, 3)                     │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 183,747 (717.76 KB)
#  Trainable params: 183,747 (717.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
new_model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = new_model.fit(train_dataset,batch_size=batch_size,validation_data=validation_ds,verbose=1,epochs=50)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 48s 866ms/step - accuracy: 0.4982 - loss: 0.9257 - val_accuracy: 0.5938 - val_loss: 0.8492
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 839ms/step - accuracy: 0.7612 - loss: 0.5392 - val_accuracy: 0.7031 - val_loss: 0.6674
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 842ms/step - accuracy: 0.8698 - loss: 0.3054 - val_accuracy: 0.8802 - val_loss: 0.3074
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 868ms/step - accuracy: 0.9033 - loss: 0.2435 - val_accuracy: 0.9167 - val_loss: 0.1695
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 873ms/step - accuracy: 0.9403 - loss: 0.1548 - val_accuracy: 0.9583 - val_loss: 0.1267
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 50s 914ms/step - accuracy: 0.9452 - loss: 0.1341 - val_accuracy: 0.9323 - val_loss: 0.1854
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 858ms/step - accuracy: 0.9238 - loss: 0.2307 - val_accuracy: 0.9323 - val_loss: 0.1807
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 834ms/step - accuracy: 0.9765 - loss: 0.0758 - val_accuracy: 0.9010 - val_loss: 0.3387
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 48s 882ms/step - accuracy: 0.9647 - loss: 0.0893 - val_accuracy: 0.8021 - val_loss: 0.6217
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 847ms/step - accuracy: 0.9713 - loss: 0.0777 - val_accuracy: 0.8906 - val_loss: 0.3356
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 864ms/step - accuracy: 0.9795 - loss: 0.0555 - val_accuracy: 0.7969 - val_loss: 0.5725
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 849ms/step - accuracy: 0.9416 - loss: 0.1652 - val_accuracy: 0.9531 - val_loss: 0.1139
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 873ms/step - accuracy: 0.9817 - loss: 0.0443 - val_accuracy: 0.9635 - val_loss: 0.0755
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 859ms/step - accuracy: 0.9836 - loss: 0.0484 - val_accuracy: 0.9635 - val_loss: 0.1229
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 819ms/step - accuracy: 0.9763 - loss: 0.0566 - val_accuracy: 0.9323 - val_loss: 0.1962
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 834ms/step - accuracy: 0.9855 - loss: 0.0428 - val_accuracy: 0.9583 - val_loss: 0.1047
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 826ms/step - accuracy: 0.9873 - loss: 0.0442 - val_accuracy: 0.9427 - val_loss: 0.1607
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 809ms/step - accuracy: 0.9794 - loss: 0.0594 - val_accuracy: 0.9427 - val_loss: 0.1899
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 809ms/step - accuracy: 0.9864 - loss: 0.0449 - val_accuracy: 0.7292 - val_loss: 1.2567
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 830ms/step - accuracy: 0.9795 - loss: 0.0656 - val_accuracy: 0.9688 - val_loss: 0.1173
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 808ms/step - accuracy: 0.9903 - loss: 0.0356 - val_accuracy: 0.9219 - val_loss: 0.2644
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 812ms/step - accuracy: 0.9624 - loss: 0.1241 - val_accuracy: 0.9635 - val_loss: 0.1089
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 814ms/step - accuracy: 0.9839 - loss: 0.0405 - val_accuracy: 0.9479 - val_loss: 0.1265
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 806ms/step - accuracy: 0.9847 - loss: 0.0498 - val_accuracy: 0.9896 - val_loss: 0.0625
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 815ms/step - accuracy: 0.9893 - loss: 0.0380 - val_accuracy: 0.9635 - val_loss: 0.0781
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 811ms/step - accuracy: 0.9902 - loss: 0.0326 - val_accuracy: 0.9740 - val_loss: 0.0997
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 816ms/step - accuracy: 0.9934 - loss: 0.0263 - val_accuracy: 0.9219 - val_loss: 0.2564
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 817ms/step - accuracy: 0.9826 - loss: 0.0371 - val_accuracy: 0.9375 - val_loss: 0.2147
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 824ms/step - accuracy: 0.9933 - loss: 0.0188 - val_accuracy: 0.8958 - val_loss: 0.4788
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 813ms/step - accuracy: 0.9698 - loss: 0.0770 - val_accuracy: 0.9479 - val_loss: 0.1238
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 814ms/step - accuracy: 0.9896 - loss: 0.0367 - val_accuracy: 0.9896 - val_loss: 0.0708
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 810ms/step - accuracy: 0.9884 - loss: 0.0308 - val_accuracy: 0.9844 - val_loss: 0.0889
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 819ms/step - accuracy: 0.9910 - loss: 0.0248 - val_accuracy: 0.9219 - val_loss: 0.1850
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 812ms/step - accuracy: 0.9482 - loss: 0.1300 - val_accuracy: 0.9792 - val_loss: 0.0622
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 805ms/step - accuracy: 0.9938 - loss: 0.0220 - val_accuracy: 0.9948 - val_loss: 0.0112
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 813ms/step - accuracy: 0.9865 - loss: 0.0358 - val_accuracy: 0.9688 - val_loss: 0.0811
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 809ms/step - accuracy: 0.9981 - loss: 0.0125 - val_accuracy: 0.9688 - val_loss: 0.0835
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 828ms/step - accuracy: 0.9884 - loss: 0.0299 - val_accuracy: 0.9792 - val_loss: 0.0671
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 842ms/step - accuracy: 0.9940 - loss: 0.0174 - val_accuracy: 0.9323 - val_loss: 0.2970
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 859ms/step - accuracy: 0.9762 - loss: 0.0588 - val_accuracy: 0.9740 - val_loss: 0.0649
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 832ms/step - accuracy: 0.9859 - loss: 0.0382 - val_accuracy: 0.9896 - val_loss: 0.0345
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 845ms/step - accuracy: 0.9930 - loss: 0.0209 - val_accuracy: 0.9271 - val_loss: 0.2080
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 840ms/step - accuracy: 0.9949 - loss: 0.0201 - val_accuracy: 0.9688 - val_loss: 0.0661
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 48s 894ms/step - accuracy: 0.9972 - loss: 0.0085 - val_accuracy: 0.9583 - val_loss: 0.1245
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 877ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.8958 - val_loss: 0.5552
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 875ms/step - accuracy: 0.9808 - loss: 0.0670 - val_accuracy: 0.9844 - val_loss: 0.0887
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 48s 878ms/step - accuracy: 0.9839 - loss: 0.0357 - val_accuracy: 0.9271 - val_loss: 0.2284
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 866ms/step - accuracy: 0.9918 - loss: 0.0244 - val_accuracy: 0.7656 - val_loss: 0.9720
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 847ms/step - accuracy: 0.9866 - loss: 0.0549 - val_accuracy: 0.9844 - val_loss: 0.0655
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 47s 873ms/step - accuracy: 0.9904 - loss: 0.0240 - val_accuracy: 0.9635 - val_loss: 0.0986

# %% [markdown]
# ### Load and upload model

# %%
# import os

model_version = 1

new_model.save(f"models/{model_version}.keras")

# %%
load_model = tf.keras.models.load_model('models/1.keras')
scores = load_model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.9514 - loss: 0.1347

# %%
scores = new_model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.9425 - loss: 0.1961

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
EPOCHS = 50
# The graph will show how much epoch is least required to get the accuracy
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch,labels_batch in test_ds.take(1):
    # print image
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print('first_image')
    plt.imshow(first_image)
    print('actual label - ',dataset_name[first_label])
    batch_prediction =  new_model.predict(images_batch)
    # print("all batches",batch_prediction)
    print('predicted label - ',dataset_name[np.argmax(batch_prediction[0])])
# Out:
# first_image
# actual label -  Potato___healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# predicted label -  Potato___healthy

# %%
def predict(model, img):
        
    
        prediction = model.predict(images_batch)

        predicted_class = dataset_name[np.argmax.prediction[0]]
        confidence = round(100*np.argmax(prediction[0]),2)
        return confidence,predicted_class

# %% [markdown]
# ### Auto increment model

# %%
# import os
# model_version = max([int(i) for i in os.listdir("../models") + [0]]) + 1
# model.save(f"../models/{model_version}")
